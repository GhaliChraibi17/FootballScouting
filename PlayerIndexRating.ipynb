# %% [markdown]
# ### Concatenate all data players from all leagues

# %%
import pandas as pd
import glob
import os

# Path to the folder containing the CSV files
folder_path = 'players_data_clean/'

# Get list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# Read and concatenate all CSV files into a single DataFrame
df_combined = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True)

# Check the resulting DataFrame
df_combined
# Out:
#                    Player   Birthdate         League                  Club  \
# 0           Amir Rrahmani  1994-02-24         SerieA                Napoli
# 1     Giovanni Di Lorenzo  1993-08-04         SerieA                Napoli
# 2           Romelu Lukaku  1993-05-13         SerieA                Napoli
# 3         Matteo Politano  1993-08-03         SerieA                Napoli
# 4         Scott McTominay  1996-12-08         SerieA                Napoli
# ...                   ...         ...            ...                   ...
# 2432    Yukinari Sugawara  2000-06-28  PremierLeague           Southampton
# 2433       Adam Armstrong  1997-02-10  PremierLeague  West Bromwich Albion
# 2434           James Bree  1997-10-11  PremierLeague           Southampton
# 2435         Paul Onuachu  1994-05-28  PremierLeague           Southampton
# 2436    William Smallbone  2000-02-21  PremierLeague           Southampton
#
#      Footed          Nationality           Position  Minutes  Goals  Assists  \
# 0     Right               Kosovo       Center Backs     3406   0.03     0.08
# 1     Right                Italy          Fullbacks     3330   0.08     0.05
# 2      Left              Belgium           Forwards     2843   0.44     0.32
# 3      Left                Italy  Att Mid / Wingers     2804   0.10     0.13
# 4     Right             Scotland        Midfielders     2938   0.37     0.12
# ...     ...                  ...                ...      ...    ...      ...
# 2432  Right                Japan          Fullbacks     1557   0.06     0.06
# 2433  Right              England           Forwards     1248   0.14     0.14
# 2434  Right              England       Center Backs     1075   0.00     0.08
# 2435  Right              Nigeria           Forwards     1050   0.34     0.09
# 2436  Right  Republic of Ireland        Midfielders      690   0.13     0.00
#
#       ...  Fouls Committed  Fouls Drawn  Offsides  Penalty Kicks Won  \
# 0     ...             1.11         0.42      0.00               0.00
# 1     ...             1.24         1.38      0.14               0.00
# 2     ...             1.49         1.14      0.76               0.00
# 3     ...             0.45         1.00      0.19               0.03
# 4     ...             1.38         1.84      0.15               0.03
# ...   ...              ...          ...       ...                ...
# 2432  ...             0.87         0.58      0.23               0.00
# 2433  ...             0.87         0.36      0.65               0.00
# 2434  ...             0.33         0.42      0.00               0.00
# 2435  ...             2.40         1.37      0.86               0.00
# 2436  ...             1.43         0.39      0.00               0.00
#
#       Penalty Kicks Conceded  Own Goals  Ball Recoveries  Aerials Won  \
# 0                       0.00       0.03             3.57         3.28
# 1                       0.00       0.00             2.54         1.22
# 2                       0.00       0.00             1.08         1.33
# 3                       0.00       0.00             3.05         0.19
# 4                       0.00       0.00             4.38         2.02
# ...                      ...        ...              ...          ...
# 2432                    0.12       0.00             2.54         0.29
# 2433                    0.00       0.00             1.66         0.36
# 2434                    0.00       0.00             5.44         1.00
# 2435                    0.00       0.00             1.63         7.97
# 2436                    0.13       0.00             3.00         0.52
#
#       Aerials Lost  % of Aerials Won
# 0             1.45              69.3
# 1             1.24              49.5
# 2             1.77              42.9
# 3             0.64              23.1
# 4             1.53              56.9
# ...            ...               ...
# 2432          0.52              35.7
# 2433          0.65              35.7
# 2434          0.59              63.2
# 2435          5.06              61.2
# 2436          0.78              40.0
#
# [2437 rows x 125 columns]

# %% [markdown]
# # Dim Reduction (2/3) - 95 variance du dataset
# # Kmeans
# # ELbow method - WithinClusterSumSquares - Silouhette
#
#
# # Distance / Cosine Sim / Gamma Mixture

# %%
# Check for NaN values in each column
nan_counts = df_combined.isna().sum()

# Display columns with NaNs and their counts
nan_columns = nan_counts[nan_counts > 0]

if nan_columns.empty:
    print("No NaN values found!")
else:
    print("NaN values detected:")
    print(nan_columns)
# Out:
# No NaN values found!

# %% [markdown]
# ### Merge clubs' elos for modelling

# %%
elo_df = pd.read_csv("elo_clubs/Elo_Club_VF.csv", sep=';')

# %%
from fuzzywuzzy import process

def get_best_match(name, choices):
    result = process.extractOne(name, choices)
    return result[0] 

# Apply fuzzy matching to club names with the same 
df_combined["Club_fuzzy"] = df_combined["Club"].apply(
    lambda x: get_best_match(x, elo_df["Club"].unique())
)

# Merge the matched names
final_df = pd.merge(df_combined, elo_df, left_on='Club_fuzzy', right_on='Club', how='left')
final_df.drop(columns=['Club_fuzzy', 'Club_y'], inplace=True)
final_df.rename(columns={'Club_x': 'Club'}, inplace=True)

# %%
final_df
# Out:
#                    Player   Birthdate         League                  Club  \
# 0           Amir Rrahmani  1994-02-24         SerieA                Napoli
# 1     Giovanni Di Lorenzo  1993-08-04         SerieA                Napoli
# 2           Romelu Lukaku  1993-05-13         SerieA                Napoli
# 3         Matteo Politano  1993-08-03         SerieA                Napoli
# 4         Scott McTominay  1996-12-08         SerieA                Napoli
# ...                   ...         ...            ...                   ...
# 2432    Yukinari Sugawara  2000-06-28  PremierLeague           Southampton
# 2433       Adam Armstrong  1997-02-10  PremierLeague  West Bromwich Albion
# 2434           James Bree  1997-10-11  PremierLeague           Southampton
# 2435         Paul Onuachu  1994-05-28  PremierLeague           Southampton
# 2436    William Smallbone  2000-02-21  PremierLeague           Southampton
#
#      Footed          Nationality           Position  Minutes  Goals  Assists  \
# 0     Right               Kosovo       Center Backs     3406   0.03     0.08
# 1     Right                Italy          Fullbacks     3330   0.08     0.05
# 2      Left              Belgium           Forwards     2843   0.44     0.32
# 3      Left                Italy  Att Mid / Wingers     2804   0.10     0.13
# 4     Right             Scotland        Midfielders     2938   0.37     0.12
# ...     ...                  ...                ...      ...    ...      ...
# 2432  Right                Japan          Fullbacks     1557   0.06     0.06
# 2433  Right              England           Forwards     1248   0.14     0.14
# 2434  Right              England       Center Backs     1075   0.00     0.08
# 2435  Right              Nigeria           Forwards     1050   0.34     0.09
# 2436  Right  Republic of Ireland        Midfielders      690   0.13     0.00
#
#       ...  Fouls Drawn  Offsides  Penalty Kicks Won  Penalty Kicks Conceded  \
# 0     ...         0.42      0.00               0.00                    0.00
# 1     ...         1.38      0.14               0.00                    0.00
# 2     ...         1.14      0.76               0.00                    0.00
# 3     ...         1.00      0.19               0.03                    0.00
# 4     ...         1.84      0.15               0.03                    0.00
# ...   ...          ...       ...                ...                     ...
# 2432  ...         0.58      0.23               0.00                    0.12
# 2433  ...         0.36      0.65               0.00                    0.00
# 2434  ...         0.42      0.00               0.00                    0.00
# 2435  ...         1.37      0.86               0.00                    0.00
# 2436  ...         0.39      0.00               0.00                    0.13
#
#       Own Goals  Ball Recoveries  Aerials Won  Aerials Lost  % of Aerials Won  \
# 0          0.03             3.57         3.28          1.45              69.3
# 1          0.00             2.54         1.22          1.24              49.5
# 2          0.00             1.08         1.33          1.77              42.9
# 3          0.00             3.05         0.19          0.64              23.1
# 4          0.00             4.38         2.02          1.53              56.9
# ...         ...              ...          ...           ...               ...
# 2432       0.00             2.54         0.29          0.52              35.7
# 2433       0.00             1.66         0.36          0.65              35.7
# 2434       0.00             5.44         1.00          0.59              63.2
# 2435       0.00             1.63         7.97          5.06              61.2
# 2436       0.00             3.00         0.52          0.78              40.0
#
#        Elo
# 0     1838
# 1     1838
# 2     1838
# 3     1838
# 4     1838
# ...    ...
# 2432  1782
# 2433  1538
# 2434  1782
# 2435  1782
# 2436  1782
#
# [2437 rows x 126 columns]

# %%
# Check for NaN values in each column
nan_counts = final_df.isna().sum()

# Display columns with NaNs and their counts
nan_columns = nan_counts[nan_counts > 0]

if nan_columns.empty:
    print("No NaN values found!")
else:
    print("NaN values detected:")
    print(nan_columns)
# Out:
# No NaN values found!

# %%
final_df[final_df['League']==""]
