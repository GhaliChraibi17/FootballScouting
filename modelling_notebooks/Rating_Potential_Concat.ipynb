# %% [markdown]
# ### Concatenate all data players from all leagues

# %%
import pandas as pd
import glob
import os

# Path to the folder containing the CSV files
folder_path = 'players_data_clean/'

# Get list of all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# Read and concatenate all CSV files into a single DataFrame
df_combined = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True)

# Check the resulting DataFrame
df_combined
# Out:
#                    Player   Birthdate         League                  Club  \
# 0           Amir Rrahmani  1994-02-24         SerieA                Napoli
# 1     Giovanni Di Lorenzo  1993-08-04         SerieA                Napoli
# 2           Romelu Lukaku  1993-05-13         SerieA                Napoli
# 3         Matteo Politano  1993-08-03         SerieA                Napoli
# 4         Scott McTominay  1996-12-08         SerieA                Napoli
# ...                   ...         ...            ...                   ...
# 2432    Yukinari Sugawara  2000-06-28  PremierLeague           Southampton
# 2433       Adam Armstrong  1997-02-10  PremierLeague  West Bromwich Albion
# 2434           James Bree  1997-10-11  PremierLeague           Southampton
# 2435         Paul Onuachu  1994-05-28  PremierLeague           Southampton
# 2436    William Smallbone  2000-02-21  PremierLeague           Southampton
#
#      Footed          Nationality           Position  Minutes  Goals  Assists  \
# 0     Right               Kosovo       Center Backs     3406   0.03     0.08
# 1     Right                Italy          Fullbacks     3330   0.08     0.05
# 2      Left              Belgium           Forwards     2843   0.44     0.32
# 3      Left                Italy  Att Mid / Wingers     2804   0.10     0.13
# 4     Right             Scotland        Midfielders     2938   0.37     0.12
# ...     ...                  ...                ...      ...    ...      ...
# 2432  Right                Japan          Fullbacks     1557   0.06     0.06
# 2433  Right              England           Forwards     1248   0.14     0.14
# 2434  Right              England       Center Backs     1075   0.00     0.08
# 2435  Right              Nigeria           Forwards     1050   0.34     0.09
# 2436  Right  Republic of Ireland        Midfielders      690   0.13     0.00
#
#       ...  Fouls Committed  Fouls Drawn  Offsides  Penalty Kicks Won  \
# 0     ...             1.11         0.42      0.00               0.00
# 1     ...             1.24         1.38      0.14               0.00
# 2     ...             1.49         1.14      0.76               0.00
# 3     ...             0.45         1.00      0.19               0.03
# 4     ...             1.38         1.84      0.15               0.03
# ...   ...              ...          ...       ...                ...
# 2432  ...             0.87         0.58      0.23               0.00
# 2433  ...             0.87         0.36      0.65               0.00
# 2434  ...             0.33         0.42      0.00               0.00
# 2435  ...             2.40         1.37      0.86               0.00
# 2436  ...             1.43         0.39      0.00               0.00
#
#       Penalty Kicks Conceded  Own Goals  Ball Recoveries  Aerials Won  \
# 0                       0.00       0.03             3.57         3.28
# 1                       0.00       0.00             2.54         1.22
# 2                       0.00       0.00             1.08         1.33
# 3                       0.00       0.00             3.05         0.19
# 4                       0.00       0.00             4.38         2.02
# ...                      ...        ...              ...          ...
# 2432                    0.12       0.00             2.54         0.29
# 2433                    0.00       0.00             1.66         0.36
# 2434                    0.00       0.00             5.44         1.00
# 2435                    0.00       0.00             1.63         7.97
# 2436                    0.13       0.00             3.00         0.52
#
#       Aerials Lost  % of Aerials Won
# 0             1.45              69.3
# 1             1.24              49.5
# 2             1.77              42.9
# 3             0.64              23.1
# 4             1.53              56.9
# ...            ...               ...
# 2432          0.52              35.7
# 2433          0.65              35.7
# 2434          0.59              63.2
# 2435          5.06              61.2
# 2436          0.78              40.0
#
# [2437 rows x 125 columns]

# %%
# Check for NaN values in each column
nan_counts = df_combined.isna().sum()

# Display columns with NaNs and their counts
nan_columns = nan_counts[nan_counts > 0]

if nan_columns.empty:
    print("No NaN values found!")
else:
    print("NaN values detected:")
    print(nan_columns)
# Out:
# No NaN values found!

# %% [markdown]
# ### Merge clubs' elos for modelling

# %%
elo_df = pd.read_csv("elo_clubs/Elo_Club_VF.csv", sep=';')

# %%
from fuzzywuzzy import process

def get_best_match(name, choices):
    result = process.extractOne(name, choices)
    return result[0] 

# Apply fuzzy matching to club names with the same 
df_combined["Club_fuzzy"] = df_combined["Club"].apply(
    lambda x: get_best_match(x, elo_df["Club"].unique())
)

# Merge the matched names
final_df = pd.merge(df_combined, elo_df, left_on='Club_fuzzy', right_on='Club', how='left')
final_df.drop(columns=['Club_fuzzy', 'Club_y'], inplace=True)
final_df.rename(columns={'Club_x': 'Club'}, inplace=True)

# %%
final_df
# Out:
#                    Player   Birthdate         League                  Club  \
# 0           Amir Rrahmani  1994-02-24         SerieA                Napoli
# 1     Giovanni Di Lorenzo  1993-08-04         SerieA                Napoli
# 2           Romelu Lukaku  1993-05-13         SerieA                Napoli
# 3         Matteo Politano  1993-08-03         SerieA                Napoli
# 4         Scott McTominay  1996-12-08         SerieA                Napoli
# ...                   ...         ...            ...                   ...
# 2432    Yukinari Sugawara  2000-06-28  PremierLeague           Southampton
# 2433       Adam Armstrong  1997-02-10  PremierLeague  West Bromwich Albion
# 2434           James Bree  1997-10-11  PremierLeague           Southampton
# 2435         Paul Onuachu  1994-05-28  PremierLeague           Southampton
# 2436    William Smallbone  2000-02-21  PremierLeague           Southampton
#
#      Footed          Nationality           Position  Minutes  Goals  Assists  \
# 0     Right               Kosovo       Center Backs     3406   0.03     0.08
# 1     Right                Italy          Fullbacks     3330   0.08     0.05
# 2      Left              Belgium           Forwards     2843   0.44     0.32
# 3      Left                Italy  Att Mid / Wingers     2804   0.10     0.13
# 4     Right             Scotland        Midfielders     2938   0.37     0.12
# ...     ...                  ...                ...      ...    ...      ...
# 2432  Right                Japan          Fullbacks     1557   0.06     0.06
# 2433  Right              England           Forwards     1248   0.14     0.14
# 2434  Right              England       Center Backs     1075   0.00     0.08
# 2435  Right              Nigeria           Forwards     1050   0.34     0.09
# 2436  Right  Republic of Ireland        Midfielders      690   0.13     0.00
#
#       ...  Fouls Drawn  Offsides  Penalty Kicks Won  Penalty Kicks Conceded  \
# 0     ...         0.42      0.00               0.00                    0.00
# 1     ...         1.38      0.14               0.00                    0.00
# 2     ...         1.14      0.76               0.00                    0.00
# 3     ...         1.00      0.19               0.03                    0.00
# 4     ...         1.84      0.15               0.03                    0.00
# ...   ...          ...       ...                ...                     ...
# 2432  ...         0.58      0.23               0.00                    0.12
# 2433  ...         0.36      0.65               0.00                    0.00
# 2434  ...         0.42      0.00               0.00                    0.00
# 2435  ...         1.37      0.86               0.00                    0.00
# 2436  ...         0.39      0.00               0.00                    0.13
#
#       Own Goals  Ball Recoveries  Aerials Won  Aerials Lost  % of Aerials Won  \
# 0          0.03             3.57         3.28          1.45              69.3
# 1          0.00             2.54         1.22          1.24              49.5
# 2          0.00             1.08         1.33          1.77              42.9
# 3          0.00             3.05         0.19          0.64              23.1
# 4          0.00             4.38         2.02          1.53              56.9
# ...         ...              ...          ...           ...               ...
# 2432       0.00             2.54         0.29          0.52              35.7
# 2433       0.00             1.66         0.36          0.65              35.7
# 2434       0.00             5.44         1.00          0.59              63.2
# 2435       0.00             1.63         7.97          5.06              61.2
# 2436       0.00             3.00         0.52          0.78              40.0
#
#        Elo
# 0     1838
# 1     1838
# 2     1838
# 3     1838
# 4     1838
# ...    ...
# 2432  1782
# 2433  1538
# 2434  1782
# 2435  1782
# 2436  1782
#
# [2437 rows x 126 columns]

# %%
final_df_am = final_df[final_df["Position"] == "Att Mid / Wingers"].copy()

# %%
final_df_am
# Out:
#                      Player   Birthdate         League                 Club  \
# 3           Matteo Politano  1993-08-03         SerieA               Napoli
# 9     Khvicha Kvaratskhelia  2001-02-12         SerieA  Paris Saint-Germain
# 10              David Neres  1997-03-03         SerieA               Napoli
# 12        Giacomo Raspadori  2000-02-18         SerieA               Napoli
# 14       Michael Folorunsho  1998-02-07         SerieA           Fiorentina
# ...                     ...         ...            ...                  ...
# 2417              Wes Burns  1994-11-23  PremierLeague         Ipswich Town
# 2418          Conor Chaplin  1997-02-16  PremierLeague         Ipswich Town
# 2419       Nathan Broadhead  1998-04-05  PremierLeague         Ipswich Town
# 2422       Mateus Fernandes  2004-07-10  PremierLeague          Southampton
# 2430     Kamaldeen Sulemana  2002-02-15  PremierLeague          Southampton
#
#      Footed Nationality           Position  Minutes  Goals  Assists  ...  \
# 3      Left       Italy  Att Mid / Wingers     2804   0.10     0.13  ...
# 9     Right     Georgia  Att Mid / Wingers     1178   0.38     0.23  ...
# 10     Left      Brazil  Att Mid / Wingers     1283   0.14     0.28  ...
# 12    Right       Italy  Att Mid / Wingers     1103   0.49     0.08  ...
# 14    Right       Italy  Att Mid / Wingers      685   0.00     0.00  ...
# ...     ...         ...                ...      ...    ...      ...  ...
# 2417  Right       Wales  Att Mid / Wingers      926   0.00     0.10  ...
# 2418  Right     England  Att Mid / Wingers      857   0.11     0.11  ...
# 2419  Right       Wales  Att Mid / Wingers      702   0.26     0.00  ...
# 2422  Right    Portugal  Att Mid / Wingers     2909   0.06     0.12  ...
# 2430  Right       Ghana  Att Mid / Wingers     1402   0.06     0.06  ...
#
#       Fouls Drawn  Offsides  Penalty Kicks Won  Penalty Kicks Conceded  \
# 3            1.00      0.19               0.03                     0.0
# 9            2.52      0.00               0.00                     0.0
# 10           0.70      0.28               0.00                     0.0
# 12           1.63      0.08               0.00                     0.0
# 14           3.15      0.00               0.00                     0.0
# ...           ...       ...                ...                     ...
# 2417         1.07      0.00               0.00                     0.0
# 2418         0.74      0.00               0.00                     0.0
# 2419         1.67      0.26               0.00                     0.0
# 2422         1.70      0.12               0.00                     0.0
# 2430         0.71      0.19               0.00                     0.0
#
#       Own Goals  Ball Recoveries  Aerials Won  Aerials Lost  % of Aerials Won  \
# 3           0.0             3.05         0.19          0.64              23.1
# 9           0.0             3.44         0.31          0.38              44.4
# 10          0.0             3.65         0.21          0.70              23.1
# 12          0.0             3.51         0.41          0.90              31.3
# 14          0.0             4.07         2.37          1.71              58.1
# ...         ...              ...          ...           ...               ...
# 2417        0.0             4.86         0.78          2.04              27.6
# 2418        0.0             2.84         0.32          0.95              25.0
# 2419        0.0             4.10         0.13          1.28               9.1
# 2422        0.0             5.54         0.46          0.28              62.5
# 2430        0.0             4.04         0.83          1.73              32.5
#
#        Elo
# 3     1838
# 9     1975
# 10    1838
# 12    1838
# 14    1757
# ...    ...
# 2417  1797
# 2418  1797
# 2419  1797
# 2422  1782
# 2430  1782
#
# [577 rows x 126 columns]

# %%
# Check for NaN values in each column
nan_counts = final_df.isna().sum()

# Display columns with NaNs and their counts
nan_columns = nan_counts[nan_counts > 0]

if nan_columns.empty:
    print("No NaN values found!")
else:
    print("NaN values detected:")
    print(nan_columns)
# Out:
# No NaN values found!

# %% [markdown]
# ### Running the positions models for all players

# %%
import joblib 

model_paths = {
    "Center Backs": "models/best_model_cb.joblib",
    "Att Mid / Wingers": "models/best_model_am.joblib",
    "Forwards": "models/best_model_fw.joblib",
    "Fullbacks": "models/best_model_fb.joblib",
    "Midfielders": "models/best_model_mid.joblib"
}

models = {pos: joblib.load(path) for pos, path in model_paths.items()}

# %%
predicted_chunks = []

for pos, pipeline in models.items():
    df_pos = final_df[final_df["Position"] == pos].copy()
    df_pos["Rating"] = pipeline.predict(df_pos)

    predicted_chunks.append(df_pos)

df_concat = pd.concat(predicted_chunks, ignore_index=True)

# %%
# Ensure birthdate is in datetime format
df_concat["Birthdate"] = pd.to_datetime(df_concat["Birthdate"], errors="coerce")

# Compute age as of today
today = pd.Timestamp.today()
df_concat["Age"] = ((today - df_concat["Birthdate"]).dt.days / 365.25).round(0)

# %% [markdown]
# ### Rating adjustment minutes played

# %%
max_minutes = df_concat["Minutes"].max()

def adjust_rating(row):
    minutes = row["Minutes"]
    rating = row["Rating"]
    
    if pd.isna(minutes):
        return rating  # fallback if minutes missing
    
    if minutes < 1000:
        return rating * (minutes / 1000) ** 0.25
    
    elif minutes > 2000:
        boost_factor = 0.03 * (minutes - 2000) / (max_minutes - 2000)
        return rating * (1 + boost_factor)
    
    else:
        return rating

df_concat["Rating_Adjusted"] = df_concat.apply(adjust_rating, axis=1)

# %%
df_concat
# Out:
#                      Player  Birthdate         League            Club Footed  \
# 0             Amir Rrahmani 1994-02-24         SerieA          Napoli  Right
# 1     Alessandro Buongiorno 1999-06-06         SerieA          Napoli   Left
# 2        Alessandro Bastoni 1999-04-13         SerieA  Internazionale   Left
# 3          Francesco Acerbi 1988-02-10         SerieA  Internazionale   Left
# 4            Stefan de Vrij 1992-02-05         SerieA  Internazionale  Right
# ...                     ...        ...            ...             ...    ...
# 2432            Jack Taylor 1998-06-23  PremierLeague    Ipswich Town   Left
# 2433           Flynn Downes 1999-01-20  PremierLeague     Southampton  Right
# 2434              Joe Aribo 1996-07-21  PremierLeague     Southampton   Left
# 2435       Lesley Ugochukwu 2004-03-26  PremierLeague     Southampton  Right
# 2436      William Smallbone 2000-02-21  PremierLeague     Southampton  Right
#
#               Nationality      Position  Minutes  Goals  Assists  ...  \
# 0                  Kosovo  Center Backs     3406   0.03     0.08  ...
# 1                   Italy  Center Backs     1924   0.05     0.00  ...
# 2                   Italy  Center Backs     2401   0.04     0.19  ...
# 3                   Italy  Center Backs     1710   0.00     0.05  ...
# 4             Netherlands  Center Backs     1726   0.16     0.00  ...
# ...                   ...           ...      ...    ...      ...  ...
# 2432  Republic of Ireland   Midfielders      860   0.10     0.00  ...
# 2433              England   Midfielders     2151   0.04     0.00  ...
# 2434              Nigeria   Midfielders     2013   0.13     0.00  ...
# 2435               France   Midfielders     1655   0.05     0.05  ...
# 2436  Republic of Ireland   Midfielders      690   0.13     0.00  ...
#
#       Penalty Kicks Conceded  Own Goals  Ball Recoveries  Aerials Won  \
# 0                       0.00       0.03             3.57         3.28
# 1                       0.00       0.00             3.93         2.01
# 2                       0.00       0.00             3.60         1.65
# 3                       0.00       0.00             3.26         3.21
# 4                       0.00       0.00             3.44         3.39
# ...                      ...        ...              ...          ...
# 2432                    0.00       0.00             5.55         0.73
# 2433                    0.00       0.00             3.47         0.71
# 2434                    0.04       0.00             5.01         1.12
# 2435                    0.05       0.00             3.64         1.09
# 2436                    0.13       0.00             3.00         0.52
#
#       Aerials Lost  % of Aerials Won   Elo     Rating   Age  Rating_Adjusted
# 0             1.45              69.3  1838  79.483861  31.0        81.050510
# 1             0.98              67.2  1838  77.809277  26.0        77.809277
# 2             0.90              64.7  1933  81.425545  26.0        81.883278
# 3             1.58              67.0  1933  79.861999  37.0        79.861999
# 4             1.98              63.1  1933  80.175203  33.0        80.175203
# ...            ...               ...   ...        ...   ...              ...
# 2432          0.84              46.7  1797  75.221898  27.0        72.438408
# 2433          0.71              50.0  1782  74.925184  26.0        75.083788
# 2434          1.07              51.0  1782  75.024692  29.0        75.038365
# 2435          0.98              52.6  1782  75.057848  21.0        75.057848
# 2436          0.78              40.0  1782  73.300390  25.0        66.806475
#
# [2437 rows x 129 columns]

# %% [markdown]
# ### Potential determinantion

# %%
import numpy as np

# Parameters
reference_elo = df_concat["Elo"].median()   # Centering point for Elo normalization
elo_weight = 0.2      # How strongly Elo affects potential
age_weight = 0.4  # Boost for younger players

# Elo boost relative to reference
df_concat["EloBoost"] = (df_concat["Elo"] - reference_elo) / reference_elo

# Age modifier: favors players under 22
df_concat["AgeModifier"] = (24 / df_concat["Age"]).clip(upper=1.5) ** age_weight

# Potential formula
df_concat["Potential"] = df_concat["Rating_Adjusted"] * (1 + df_concat["EloBoost"] * elo_weight) * df_concat["AgeModifier"]

# Ensure Potential is at least as high as the current adjusted rating
df_concat["Potential"] = np.maximum(df_concat["Potential"], df_concat["Rating_Adjusted"])

# %%
df_concat.sort_values("Potential", ascending=False).head(30)
# Out:
#                   Player  Birthdate         League                 Club  \
# 612         Lamine Yamal 2007-07-13         LaLiga            Barcelona
# 751          Désiré Doué 2005-06-03         Ligue1  Paris Saint-Germain
# 618           Arda Güler 2005-02-25         LaLiga          Real Madrid
# 954          Cole Palmer 2002-05-06  PremierLeague              Chelsea
# 947          Bukayo Saka 2001-09-05  PremierLeague              Arsenal
# 2010     Jude Bellingham 2003-06-29         LaLiga          Real Madrid
# 1211       Gonçalo Ramos 2001-06-20         Ligue1  Paris Saint-Germain
# 941        Mohamed Salah 1992-06-15  PremierLeague            Liverpool
# 2248      Ismael Saibari 2001-01-28     Eredivisie        PSV Eindhoven
# 510        Jamal Musiala 2003-02-26     Bundesliga        Bayern Munich
# 1961      Geovany Quenda 2007-04-30   PrimeiraLiga          Sporting CP
# 264        Lucas Beraldo 2003-11-24         Ligue1  Paris Saint-Germain
# 2005               Pedri 2002-11-25         LaLiga            Barcelona
# 2007                Gavi 2004-08-05         LaLiga            Barcelona
# 1618         Nuno Mendes 2002-06-19         Ligue1  Paris Saint-Germain
# 460         Kenan Yıldız 2005-05-04         SerieA             Juventus
# 515        Florian Wirtz 2003-05-03     Bundesliga           Leverkusen
# 1970    Nicolás González 2002-01-03   PrimeiraLiga      Manchester City
# 2364    Ryan Gravenberch 2002-05-16  PremierLeague            Liverpool
# 509        Michael Olise 2001-12-12     Bundesliga        Bayern Munich
# 1778          Rico Lewis 2004-11-21  PremierLeague      Manchester City
# 770         Rayan Cherki 2003-08-17         Ligue1                 Lyon
# 1777      Joško Gvardiol 2002-01-23  PremierLeague      Manchester City
# 750          Lee Kang-in 2001-02-19         Ligue1  Paris Saint-Germain
# 1786          Lewis Hall 2004-09-08  PremierLeague     Newcastle United
# 758   Eliesse Ben Seghir 2005-02-16         Ligue1               Monaco
# 2197       Lamine Camara 2004-01-01         Ligue1               Monaco
# 1130       Kylian Mbappé 1998-12-20         LaLiga          Real Madrid
# 413         Dean Huijsen 2005-04-14  PremierLeague          Bournemouth
# 946   Gabriel Martinelli 2001-06-18  PremierLeague              Arsenal
#
#      Footed     Nationality           Position  Minutes  Goals  Assists  ...  \
# 612    Left           Spain  Att Mid / Wingers     2856   0.28     0.41  ...
# 751   Right          France  Att Mid / Wingers     1730   0.31     0.31  ...
# 618    Left          Turkey  Att Mid / Wingers     1250   0.22     0.29  ...
# 954    Left         England  Att Mid / Wingers     3191   0.42     0.23  ...
# 947    Left         England  Att Mid / Wingers     1729   0.31     0.52  ...
# 2010  Right         England        Midfielders     2488   0.33     0.29  ...
# 1211  Right        Portugal           Forwards     1066   0.84     0.25  ...
# 941    Left           Egypt  Att Mid / Wingers     3371   0.77     0.48  ...
# 2248  Right         Morocco        Midfielders     1782   0.56     0.56  ...
# 510   Right         Germany  Att Mid / Wingers     1798   0.60     0.10  ...
# 1961   Left        Portugal        Midfielders     2253   0.08     0.16  ...
# 264   Right          Brazil       Center Backs     2011   0.04     0.00  ...
# 2005  Right           Spain        Midfielders     2879   0.13     0.16  ...
# 2007  Right           Spain        Midfielders     1085   0.08     0.08  ...
# 1618   Left        Portugal          Fullbacks     1676   0.05     0.16  ...
# 460   Right          Turkey  Att Mid / Wingers     2402   0.26     0.15  ...
# 515   Right         Germany  Att Mid / Wingers     2351   0.38     0.46  ...
# 1970  Right           Spain        Midfielders     1441   0.31     0.19  ...
# 2364  Right     Netherlands        Midfielders     3160   0.00     0.11  ...
# 509    Left          France  Att Mid / Wingers     2334   0.46     0.58  ...
# 1778  Right         England          Fullbacks     1893   0.05     0.10  ...
# 770    Both          France  Att Mid / Wingers     2041   0.35     0.49  ...
# 1777   Left         Croatia          Fullbacks     3277   0.14     0.00  ...
# 750    Left  Korea Republic  Att Mid / Wingers     1663   0.32     0.32  ...
# 1786   Left         England          Fullbacks     2189   0.00     0.16  ...
# 758   Right         Morocco  Att Mid / Wingers     1750   0.31     0.15  ...
# 2197  Right         Senegal        Midfielders     2054   0.09     0.31  ...
# 1130  Right          France           Forwards     2907   0.96     0.09  ...
# 413   Right           Spain       Center Backs     2427   0.11     0.07  ...
# 946   Right          Brazil  Att Mid / Wingers     2290   0.31     0.16  ...
#
#       Aerials Won  Aerials Lost  % of Aerials Won   Elo     Rating   Age  \
# 612          0.03          0.09              25.0  1945  83.178469  18.0
# 751          0.42          0.52              44.4  1975  83.083282  20.0
# 618          0.50          0.79              38.9  1936  83.311959  20.0
# 954          0.06          0.20              22.2  1903  84.997289  23.0
# 947          0.52          1.04              33.3  1993  86.839198  24.0
# 2010         1.09          1.12              49.2  1936  83.776238  22.0
# 1211         1.69          1.27              57.1  1975  85.746987  24.0
# 941          0.24          0.37              39.1  1993  87.623776  33.0
# 2248         0.61          0.71              46.2  1797  87.183206  24.0
# 510          0.35          0.70              33.3  1919  82.707762  22.0
# 1961         0.60          0.72              45.5  1789  77.192724  18.0
# 264          2.01          0.94              68.2  1975  81.742127  22.0
# 2005         0.22          0.19              53.8  1945  82.268526  23.0
# 2007         1.74          2.16              44.7  1945  80.182752  21.0
# 1618         0.81          0.59              57.7  1975  82.692437  23.0
# 460          0.30          0.97              23.5  1806  79.313990  20.0
# 515          0.34          1.38              20.0  1849  82.007076  22.0
# 1970         1.81          2.25              44.6  1960  82.606523  23.0
# 2364         0.74          0.40              65.0  1993  80.699732  23.0
# 509          0.42          0.46              47.8  1919  83.656632  24.0
# 1778         0.29          0.67              30.0  1960  79.153169  21.0
# 770          0.18          0.35              33.3  1745  82.458818  22.0
# 1777         1.48          1.13              56.8  1960  80.386477  23.0
# 750          0.27          0.54              33.3  1975  83.008858  24.0
# 1786         1.23          1.27              49.2  1869  79.431109  21.0
# 758          0.67          1.13              37.1  1762  79.078195  20.0
# 2197         0.92          0.92              50.0  1762  80.559662  21.0
# 1130         0.12          0.19              40.0  1936  84.893573  26.0
# 413          2.52          1.63              60.7  1808  78.035773  20.0
# 946          0.67          1.53              30.4  1993  82.008760  24.0
#
#       Rating_Adjusted  EloBoost  AgeModifier  Potential
# 612         84.176611  0.189602     1.121955  98.023683
# 751         83.083282  0.207951     1.075654  93.085714
# 618         83.311959  0.184098     1.075654  92.914401
# 954         86.416426  0.163914     1.017170  90.781780
# 947         86.839198  0.218960     1.000000  90.642065
# 2010        84.349361  0.184098     1.035417  90.552493
# 1211        85.746987  0.207951     1.000000  89.313222
# 941         89.307872  0.218960     0.880398  89.307872
# 2248        87.183206  0.099083     1.000000  88.910873
# 510         82.707762  0.173700     1.035417  88.612085
# 1961        77.466506  0.094190     1.121955  88.551223
# 264         81.754732  0.207951     1.035417  88.170888
# 2005        83.282274  0.189602     1.017170  87.924523
# 2007        80.182752  0.189602     1.054865  87.789348
# 1618        82.692437  0.207951     1.017170  87.610476
# 460         79.760965  0.104587     1.075654  87.589796
# 515         82.410597  0.130887     1.035417  87.563057
# 1970        82.606523  0.198777     1.017170  87.365280
# 2364        82.012045  0.218960     1.017170  87.073297
# 509         84.048333  0.173700     1.000000  86.968177
# 1778        79.153169  0.198777     1.054865  86.815296
# 770         82.506213  0.067278     1.035417  86.577856
# 1777        81.825546  0.198777     1.017170  86.539312
# 750         83.008858  0.207951     1.000000  86.461214
# 1786        79.641564  0.143119     1.054865  86.415800
# 758         79.078195  0.077676     1.075654  86.382191
# 2197        80.620646  0.077676     1.054865  86.365049
# 1130        85.972990  0.184098     0.968490  86.329729
# 413         78.502894  0.105810     1.075654  86.228899
# 946         82.342161  0.218960     1.000000  85.948092
#
# [30 rows x 132 columns]

# %%
df_concat.drop(columns=["AgeModifier", "EloBoost", "Rating"], inplace=True)

# %%
df_concat.rename(columns={"Rating_Adjusted": "Rating"}, inplace=True)

# %%
df_concat.to_csv("players_rating_potential_database.csv", index=False)
